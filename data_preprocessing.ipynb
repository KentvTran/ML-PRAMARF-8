# %%
#converting sas -> csv
import pyreadstat

# Read the SAS file 
sasfile_path = 'C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/phase8_arf_2016_2022.sas7bdat'
df, meta = pyreadstat.read_sas7bdat(sasfile_path)

# Save as CSV
csvfile_path = 'C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/rawPhase8ARF.csv'
df.to_csv(csvfile_path, index=False)

print("Conversion complete!")

# %%
#Checking missing data value rates
import pandas as pd

csvfile_path = 'C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/rawPhase8ARF.csv'

rawPhase8ARF = pd.read_csv(csvfile_path)

#chosen based on relevance to question
variables_of_interest = [
    "ID", "STATE", "HISPANIC", 
    "MOM_LBKG", "BPG_DIAB8", "BPG_HBP8", "BPG_DEPRS8",
    "HTH_ASMA", "HTH_IRON", "HTH_HRT", "HTH_SEIZ", "HTH_THYR", "HTH_PCOS", "HTH_ANX", "HTH_SC",
    "TLK_WT_RAW", "ASK_MEDS_RAW", "TLK_CIGS_RAW", "TLK_ETOH_RAW", "ASK_ABUS_RAW", "ASK_DPRS_RAW",
    "ASK_DRUG_RAW", "ASK_HIVT_RAW", "ASK_BF_RAW", "ASK_PPBC_RAW", "ASK_MERC_RAW", "ASK_LABR_RAW",
    "ASK_BDEF_RAW", "ASK_LEAD_RAW", "ASK_2HSM_RAW",
    "PG_GDB8", "MORB_BP8", "MH_PGDX8", "PG8_ASMA", "PG8_IRON", "PG8_HRT", "PG8_SEIZ", "PG8_THYR", "PG8_PCOS",
    "PG8_ANX", "PG8_GUM", "PG8_UTI", "PG8_NAUS", "PG8_SC", "PG8_PRET",
    "PAB6HUS", "PAB_XHUS", "PAB_FAM", "PAB_OTH", "PAD6HUS", "PAD_XHUS", "PAD_FAM", "PAD_OTH",
    "INCOME8", "MARRIED" , "MAT_DEG" , "ILLB_MO", "MAT_WIC", "MAT_RACE_PU", "PAT_RACE_PU", 
    "PAT_ACK", "PAT_DEG", "PAY"
]

data_of_interest = rawPhase8ARF[variables_of_interest]

missing_value_rate = data_of_interest.isnull().mean() * 100

# Print the missing value rate for each variable
print("Missing Value Rate (%):")
for col, missing_rate in missing_value_rate.items():
    print(f"{col}: {missing_rate:.2f}%")# Cleaning Data v2: Replace NA with Mode for Categorical & Median for Numerical, Remove Outliers, and Map States to Numbers
# Out:
# C:\Users\kentv\AppData\Local\Temp\ipykernel_18236\3670973884.py:6: DtypeWarning: Columns (459,462,463,464,465,466) have mixed types. Specify dtype option on import or set low_memory=False.
#   rawPhase8ARF = pd.read_csv(csvfile_path)
# Missing Value Rate (%):
# ID: 0.00%
# STATE: 0.00%
# HISPANIC: 3.20%
# MOM_LBKG: 1.88%
# BPG_DIAB8: 1.15%
# BPG_HBP8: 0.99%
# BPG_DEPRS8: 0.97%
# HTH_ASMA: 48.69%
# HTH_IRON: 69.48%
# HTH_HRT: 77.12%
# HTH_SEIZ: 75.37%
# HTH_THYR: 52.58%
# HTH_PCOS: 55.94%
# HTH_ANX: 51.39%
# HTH_SC: 98.26%
# TLK_WT_RAW: 3.34%
# ASK_MEDS_RAW: 2.55%
# TLK_CIGS_RAW: 2.46%
# TLK_ETOH_RAW: 2.56%
# ASK_ABUS_RAW: 2.89%
# ASK_DPRS_RAW: 2.77%
# ASK_DRUG_RAW: 2.78%
# ASK_HIVT_RAW: 4.29%
# ASK_BF_RAW: 2.64%
# ASK_PPBC_RAW: 2.77%
# ASK_MERC_RAW: 96.79%
# ASK_LABR_RAW: 96.78%
# ASK_BDEF_RAW: 96.76%
# ASK_LEAD_RAW: 96.59%
# ASK_2HSM_RAW: 96.55%
# PG_GDB8: 1.42%
# MORB_BP8: 1.55%
# MH_PGDX8: 1.83%
# PG8_ASMA: 91.14%
# PG8_IRON: 92.57%
# PG8_HRT: 95.69%
# PG8_SEIZ: 92.61%
# PG8_THYR: 95.61%
# PG8_PCOS: 100.00%
# PG8_ANX: 83.92%
# PG8_GUM: 98.23%
# PG8_UTI: 95.63%
# PG8_NAUS: 95.62%
# PG8_SC: 98.30%
# PG8_PRET: 96.91%
# PAB6HUS: 2.01%
# PAB_XHUS: 2.59%
# PAB_FAM: 53.14%
# PAB_OTH: 34.24%
# PAD6HUS: 2.07%
# PAD_XHUS: 2.73%
# PAD_FAM: 53.17%
# PAD_OTH: 34.28%
# INCOME8: 9.21%
# MARRIED: 0.08%
# MAT_DEG: 0.93%
# ILLB_MO: 41.08%
# MAT_WIC: 1.54%
# MAT_RACE_PU: 5.45%
# PAT_RACE_PU: 18.63%
# PAT_ACK: 58.60%
# PAT_DEG: 15.02%
# PAY: 0.76%

# %%
#Cleaning Data 
import pandas as pd

# Load data
csvfile_path = 'C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/rawPhase8ARF.csv'
rawPhase8ARF = pd.read_csv(csvfile_path, low_memory=False)

# Define variables of interest and target
variables_of_interest = [
    # identifier
    "ID",
    # categorical (Everything is Yes/No) except State, MAT_RACE_PU, PAT_RACE_PU 
    # demographics
    "STATE", "MAT_RACE_PU", "PAT_RACE_PU", "HISPANIC", "MARRIED", "MAT_WIC", "PAT_ACK",
    # health problem
    "BPG_DIAB8", "BPG_HBP8", "BPG_DEPRS8", "HTH_ASMA", "HTH_THYR", "HTH_PCOS", "HTH_ANX",
    # questionnaire
    "TLK_WT_RAW", "ASK_MEDS_RAW", "TLK_CIGS_RAW", "TLK_ETOH_RAW", "ASK_ABUS_RAW", 
    "ASK_DPRS_RAW", "ASK_DRUG_RAW", "ASK_HIVT_RAW", "ASK_BF_RAW", "ASK_PPBC_RAW",
    # health problem during pregnancy
    "PG_GDB8", "MORB_BP8", "MH_PGDX8",
    # abuse during and before pregnancy
    "PAB6HUS", "PAB_XHUS", "PAB_FAM", "PAB_OTH", "PAD6HUS", "PAD_XHUS", "PAD_FAM", "PAD_OTH",
    # ordinal demographics
    "MAT_DEG", "PAT_DEG", "PAY",
    # numerical
    "INCOME8", "MOM_LBKG", "ILLB_MO"  # note INCOME8 is binned
]

target_variables = ["INF_LIVE"]

# Select variables of interest
cleaned_data = rawPhase8ARF[variables_of_interest + target_variables].copy()

# Drop rows with missing target values
cleaned_data.dropna(subset=target_variables, inplace=True)

# Separate numerical and categorical variables
numerical_vars = ["MOM_LBKG", "ILLB_MO", "INCOME8"]  # INCOME8 considered numerical despite being ordinal
categorical_vars = [col for col in variables_of_interest if col not in numerical_vars + ["ID", "STATE"]]

# Replace missing values: median for numerical, mode for categorical
for column in numerical_vars:
    median_value = cleaned_data[column].median()
    cleaned_data[column] = cleaned_data[column].fillna(median_value)

for column in categorical_vars:
    mode_value = cleaned_data[column].mode()[0]
    cleaned_data[column] = cleaned_data[column].fillna(mode_value)

# Remove outliers from numerical variables using the IQR method
for var in numerical_vars:
    Q1 = cleaned_data[var].quantile(0.25)
    Q3 = cleaned_data[var].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    cleaned_data = cleaned_data[(cleaned_data[var] >= lower_bound) & (cleaned_data[var] <= upper_bound)]

# Reorder columns to keep target at the end
cleaned_data = cleaned_data[[col for col in cleaned_data.columns if col not in target_variables] + target_variables]

# Map states to numerical values
state_mapping = {
    "AK": 1, "AL": 2, "AR": 3, "AZ": 4, "CO": 5, "DC": 6, "DE": 7,
    "GA": 8, "HI": 9, "IA": 10, "IL": 11, "IN": 12, "KS": 13, "KY": 14,
    "LA": 15, "MA": 16, "MD": 17, "ME": 18, "MI": 19, "MN": 20, "MO": 21,
    "MP": 22, "MS": 23, "MT": 24, "NE": 25, "NH": 26, "NJ": 27, "NM": 28,
    "NY": 29, "OR": 30, "PA": 31, "PR": 32, "RI": 33, "SD": 34, "TN": 35,
    "UT": 36, "VA": 37, "VT": 38, "WA": 39, "WI": 40, "WV": 41, "WY": 42,
    "YC": 43
}

# Map state codes and drop rows with unmapped states
cleaned_data['STATE'] = cleaned_data['STATE'].map(state_mapping)
cleaned_data.dropna(subset=['STATE'], inplace=True)

# Save the cleaned data
output_file_path = "C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/cleanPhase8ARFv1.csv"
cleaned_data.to_csv(output_file_path, index=False)

print(f"Cleaned dataset saved to {output_file_path}")
# Out:
# Cleaned dataset saved to C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/cleanPhase8ARFv1.csv

# %%
#EDA Plotting Numerical Variables
import pandas as pd
import matplotlib.pyplot as plt

csvfile_path = 'C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/cleanPhase8ARFv1.csv'
data = pd.read_csv(csvfile_path, low_memory=False)

numerical_vars = ["INCOME8", "MOM_LBKG", "ILLB_MO", ]
target_var = "INF_LIVE"

# Plot numerical variables against INF_LIVE 
for var in numerical_vars:
    plt.figure(figsize=(8, 5))
    data.boxplot(column=var, by=target_var)
    plt.title(f'{var} vs {target_var}')
    plt.suptitle("") 
    plt.xlabel(target_var)
    plt.ylabel(var)
    plt.show()

# %%
#EDA Plotting Categorical Variables 
import pandas as pd
import matplotlib.pyplot as plt

csvfile_path = 'C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/cleanPhase8ARFv1.csv'
data = pd.read_csv(csvfile_path, low_memory=False)

categorical_vars = [
#categorical (Everything is Yes/No) except State, MAT_RACE_PU, PAT_RACE_PU 
     #demographics
    "STATE","MAT_RACE_PU", "PAT_RACE_PU", "HISPANIC", "MARRIED", "MAT_WIC", "PAT_ACK", 
    #health problem,
    "BPG_DIAB8", "BPG_HBP8", "BPG_DEPRS8", "HTH_ASMA","HTH_THYR","HTH_PCOS", "HTH_ANX",
    #questionare 
    "TLK_WT_RAW","ASK_MEDS_RAW", "TLK_CIGS_RAW", "TLK_ETOH_RAW", "ASK_ABUS_RAW", "ASK_DPRS_RAW", "ASK_DRUG_RAW", "ASK_HIVT_RAW", "ASK_BF_RAW", "ASK_PPBC_RAW",
    #health problem during pregnancy
    "PG_GDB8", "MORB_BP8", "MH_PGDX8",
    #abuse during and before pregnancy
    "PAB6HUS", "PAB_XHUS", "PAB_FAM", "PAB_OTH", "PAD6HUS", "PAD_XHUS", "PAD_FAM", "PAD_OTH",
    #ordinal demographics
    "MAT_DEG", "PAT_DEG", "PAY"
]
target_var = "INF_LIVE"

# Plot each categorical variable against INF_LIVE
for var in categorical_vars:
    plt.figure(figsize=(8, 5))
    
    ct = pd.crosstab(data[target_var], data[var], normalize='index')
    
    # Plot a stacked bar chart
    ct.plot(kind='bar', stacked=True, ax=plt.gca(), colormap="tab20")
    plt.xlabel(target_var)
    plt.ylabel(f'Proportion of {var}')
    plt.title(f'{target_var} vs {var}')
    plt.legend(title=var, bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\kentv\AppData\Local\Temp\ipykernel_18236\1663546026.py:37: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
#Correlation Between Variable of Interest and Target 
import pandas as pd
from scipy.stats import pointbiserialr, chi2_contingency
import numpy as np

csvfile_path = 'C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/cleanPhase8ARFv1.csv'
data = pd.read_csv(csvfile_path, low_memory=False)

numerical_vars = ["MOM_LBKG", "ILLB_MO", "INCOME8"]
categorical_vars = [
    "STATE","MAT_RACE_PU", "PAT_RACE_PU", "HISPANIC", "MARRIED", "MAT_WIC", "PAT_ACK", 
    "BPG_DIAB8", "BPG_HBP8", "BPG_DEPRS8", "HTH_ASMA","HTH_THYR","HTH_PCOS", "HTH_ANX",
    "TLK_WT_RAW","ASK_MEDS_RAW", "TLK_CIGS_RAW", "TLK_ETOH_RAW", "ASK_ABUS_RAW", "ASK_DPRS_RAW", "ASK_DRUG_RAW", "ASK_HIVT_RAW", "ASK_BF_RAW", "ASK_PPBC_RAW",
    "PG_GDB8", "MORB_BP8", "MH_PGDX8",
    "PAB6HUS", "PAB_XHUS", "PAB_FAM", "PAB_OTH", "PAD6HUS", "PAD_XHUS", "PAD_FAM", "PAD_OTH",
    "MAT_DEG", "PAT_DEG", "PAY"
]
target_var = "INF_LIVE"

# Point Biserial Correlation for binary (INF_LIVE) and numerical variables
print("Point Biserial Correlation (Numerical vs Target Variable):")
for var in numerical_vars:
    # Fill NaN values with the mode for each variable
    filled_var = data[var].fillna(data[var].mode()[0])
    corr, p_value = pointbiserialr(data[target_var], filled_var)
    print(f"{var} - Correlation: {corr:.3f}, p-value: {p_value:.3f}")

# Chi-square test for categorical variables
print("\nChi-Square Test (Categorical vs Target Variable):")
for var in categorical_vars:
    contingency_table = pd.crosstab(data[var].fillna(data[var].mode()[0]), data[target_var])
    chi2, p, dof, ex = chi2_contingency(contingency_table)
    print(f"{var} - Chi2: {chi2:.3f}, p-value: {p:.3f}")

# Pearson Correlation for numerical variables (including INF_LIVE as binary for correlation matrix)
print("\nPearson Correlation Matrix (Including INF_LIVE and Numerical Variables):")
data[target_var] = data[target_var].astype(int)  # Ensure INF_LIVE is numeric for correlation matrix
correlation_matrix = data[[target_var] + numerical_vars].corr(method="pearson")
print(correlation_matrix)
# Out:
# Point Biserial Correlation (Numerical vs Target Variable):
# MOM_LBKG - Correlation: -0.017, p-value: 0.000
# ILLB_MO - Correlation: -0.001, p-value: 0.783
# INCOME8 - Correlation: 0.020, p-value: 0.000
#
# Chi-Square Test (Categorical vs Target Variable):
# STATE - Chi2: 451.690, p-value: 0.000
# MAT_RACE_PU - Chi2: 74.264, p-value: 0.000
# PAT_RACE_PU - Chi2: 25.417, p-value: 0.000
# HISPANIC - Chi2: 0.583, p-value: 0.445
# MARRIED - Chi2: 39.398, p-value: 0.000
# MAT_WIC - Chi2: 0.743, p-value: 0.389
# PAT_ACK - Chi2: 49.634, p-value: 0.000
# BPG_DIAB8 - Chi2: 5.597, p-value: 0.018
# BPG_HBP8 - Chi2: 16.678, p-value: 0.000
# BPG_DEPRS8 - Chi2: 28.162, p-value: 0.000
# HTH_ASMA - Chi2: 2.996, p-value: 0.083
# HTH_THYR - Chi2: 0.984, p-value: 0.321
# HTH_PCOS - Chi2: 32.481, p-value: 0.000
# HTH_ANX - Chi2: 21.403, p-value: 0.000
# TLK_WT_RAW - Chi2: 6.757, p-value: 0.009
# ASK_MEDS_RAW - Chi2: 23.464, p-value: 0.000
# TLK_CIGS_RAW - Chi2: 31.430, p-value: 0.000
# TLK_ETOH_RAW - Chi2: 31.166, p-value: 0.000
# ASK_ABUS_RAW - Chi2: 28.338, p-value: 0.000
# ASK_DPRS_RAW - Chi2: 26.293, p-value: 0.000
# ASK_DRUG_RAW - Chi2: 9.873, p-value: 0.002
# ASK_HIVT_RAW - Chi2: 4.189, p-value: 0.041
# ASK_BF_RAW - Chi2: 205.620, p-value: 0.000
# ASK_PPBC_RAW - Chi2: 347.221, p-value: 0.000
# PG_GDB8 - Chi2: 14.981, p-value: 0.000
# MORB_BP8 - Chi2: 0.821, p-value: 0.365
# MH_PGDX8 - Chi2: 36.598, p-value: 0.000
# PAB6HUS - Chi2: 0.380, p-value: 0.538
# PAB_XHUS - Chi2: 1.193, p-value: 0.275
# PAB_FAM - Chi2: 4.548, p-value: 0.033
# PAB_OTH - Chi2: 2.050, p-value: 0.152
# PAD6HUS - Chi2: 0.172, p-value: 0.678
# PAD_XHUS - Chi2: 1.042, p-value: 0.307
# PAD_FAM - Chi2: 10.313, p-value: 0.001
# PAD_OTH - Chi2: 1.245, p-value: 0.264
# MAT_DEG - Chi2: 101.043, p-value: 0.000
# PAT_DEG - Chi2: 99.492, p-value: 0.000
# PAY - Chi2: 56.194, p-value: 0.000
#
# Pearson Correlation Matrix (Including INF_LIVE and Numerical Variables):
#           INF_LIVE  MOM_LBKG   ILLB_MO   INCOME8
# INF_LIVE  1.000000 -0.016543 -0.000666  0.019618
# MOM_LBKG -0.016543  1.000000  0.003088 -0.022459
# ILLB_MO  -0.000666  0.003088  1.000000 -0.035265
# INCOME8   0.019618 -0.022459 -0.035265  1.000000

# %%
#Correlation Between Variable of Interest and Target v2 (Check Later)
import pandas as pd
from scipy.stats import pointbiserialr, chi2_contingency, spearmanr
import numpy as np

# Load data
csvfile_path = 'C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/cleanPhase8ARFv1.csv'
data = pd.read_csv(csvfile_path)

# Define variables by type
binary_categorical_vars = [
    "HISPANIC", "MARRIED", "MAT_WIC", "PAT_ACK", "BPG_DIAB8", "BPG_HBP8", "BPG_DEPRS8",
    "HTH_ASMA", "HTH_THYR", "HTH_PCOS", "HTH_ANX", "TLK_WT_RAW", "ASK_MEDS_RAW",
    "TLK_CIGS_RAW", "TLK_ETOH_RAW", "ASK_ABUS_RAW", "ASK_DPRS_RAW", "ASK_DRUG_RAW",
    "ASK_HIVT_RAW", "ASK_BF_RAW", "ASK_PPBC_RAW", "PG_GDB8", "MORB_BP8", "MH_PGDX8",
    "PAB6HUS", "PAB_XHUS", "PAB_FAM", "PAB_OTH", "PAD6HUS", "PAD_XHUS", "PAD_FAM", "PAD_OTH"
]

ordinal_categorical_vars = ["INCOME8", "MAT_DEG", "PAT_DEG", "PAY"]
regular_categorical_vars = ["STATE", "MAT_RACE_PU", "PAT_RACE_PU"]
numerical_vars = ["INCOME8", "MOM_LBKG", "ILLB_MO"]
target_var = "INF_LIVE"

# Ensure target variable is numeric for calculations
data[target_var] = data[target_var].astype(int)

# Point Biserial Correlation for binary target and numerical variables
print("Point Biserial Correlation (Numerical vs Target Variable):")
for var in numerical_vars:
    if var != target_var:  # Exclude target from itself
        # Fill NaN values with the mode for each variable
        filled_var = data[var].fillna(data[var].mode()[0])
        corr, p_value = pointbiserialr(data[target_var], filled_var)
        print(f"{var} - Correlation: {corr:.3f}, p-value: {p_value:.3f}")

# Chi-square test for binary categorical and regular categorical variables
print("\nChi-Square Test (Binary Categorical vs Target Variable):")
for var in binary_categorical_vars:
    contingency_table = pd.crosstab(data[var].fillna(data[var].mode()[0]), data[target_var])
    chi2, p, dof, ex = chi2_contingency(contingency_table)
    print(f"{var} - Chi2: {chi2:.3f}, p-value: {p:.3f}")

print("\nChi-Square Test (Regular Categorical vs Target Variable):")
for var in regular_categorical_vars:
    contingency_table = pd.crosstab(data[var].fillna(data[var].mode()[0]), data[target_var])
    chi2, p, dof, ex = chi2_contingency(contingency_table)
    print(f"{var} - Chi2: {chi2:.3f}, p-value: {p:.3f}")

# Spearman Correlation for ordinal categorical variables
print("\nSpearman Correlation (Ordinal Categorical vs Target Variable):")
for var in ordinal_categorical_vars:
    # Fill NaN values with mode, then calculate Spearman correlation
    filled_var = data[var].fillna(data[var].mode()[0])
    corr, p_value = spearmanr(data[target_var], filled_var)
    print(f"{var} - Spearman Correlation: {corr:.3f}, p-value: {p_value:.3f}")

# Pearson Correlation Matrix (Numerical variables only)
print("\nPearson Correlation Matrix (Numerical Variables Only):")
numerical_data = data[[target_var] + numerical_vars].fillna(data.mode().iloc[0])  # Fill NaNs with mode for matrix
correlation_matrix = numerical_data.corr(method="pearson")
print(correlation_matrix)
# Out:
# Point Biserial Correlation (Numerical vs Target Variable):
# INCOME8 - Correlation: 0.002, p-value: 0.303
# MOM_LBKG - Correlation: -0.016, p-value: 0.000
# ILLB_MO - Correlation: 0.007, p-value: 0.000
#
# Chi-Square Test (Binary Categorical vs Target Variable):
# HISPANIC - Chi2: 3.073, p-value: 0.080
# MARRIED - Chi2: 45.142, p-value: 0.000
# MAT_WIC - Chi2: 1.940, p-value: 0.164
# PAT_ACK - Chi2: 74.984, p-value: 0.000
# BPG_DIAB8 - Chi2: 18.653, p-value: 0.000
# BPG_HBP8 - Chi2: 41.813, p-value: 0.000
# BPG_DEPRS8 - Chi2: 34.531, p-value: 0.000
# HTH_ASMA - Chi2: 6.350, p-value: 0.012
# HTH_THYR - Chi2: 2.382, p-value: 0.123
# HTH_PCOS - Chi2: 37.859, p-value: 0.000
# HTH_ANX - Chi2: 42.933, p-value: 0.000
# TLK_WT_RAW - Chi2: 3.875, p-value: 0.049
# ASK_MEDS_RAW - Chi2: 43.928, p-value: 0.000
# TLK_CIGS_RAW - Chi2: 60.929, p-value: 0.000
# TLK_ETOH_RAW - Chi2: 62.948, p-value: 0.000
# ASK_ABUS_RAW - Chi2: 28.227, p-value: 0.000
# ASK_DPRS_RAW - Chi2: 31.669, p-value: 0.000
# ASK_DRUG_RAW - Chi2: 16.225, p-value: 0.000
# ASK_HIVT_RAW - Chi2: 6.389, p-value: 0.011
# ASK_BF_RAW - Chi2: 274.370, p-value: 0.000
# ASK_PPBC_RAW - Chi2: 394.227, p-value: 0.000
# PG_GDB8 - Chi2: 26.653, p-value: 0.000
# MORB_BP8 - Chi2: 0.155, p-value: 0.694
# MH_PGDX8 - Chi2: 54.944, p-value: 0.000
# PAB6HUS - Chi2: 1.287, p-value: 0.257
# PAB_XHUS - Chi2: 7.406, p-value: 0.007
# PAB_FAM - Chi2: 6.441, p-value: 0.011
# PAB_OTH - Chi2: 4.213, p-value: 0.040
# PAD6HUS - Chi2: 1.602, p-value: 0.206
# PAD_XHUS - Chi2: 5.344, p-value: 0.021
# PAD_FAM - Chi2: 24.035, p-value: 0.000
# PAD_OTH - Chi2: 10.602, p-value: 0.001
#
# Chi-Square Test (Regular Categorical vs Target Variable):
# STATE - Chi2: 642.718, p-value: 0.000
# MAT_RACE_PU - Chi2: 89.519, p-value: 0.000
# PAT_RACE_PU - Chi2: 34.375, p-value: 0.000
#
# Spearman Correlation (Ordinal Categorical vs Target Variable):
# INCOME8 - Spearman Correlation: 0.016, p-value: 0.000
# MAT_DEG - Spearman Correlation: 0.021, p-value: 0.000
# PAT_DEG - Spearman Correlation: 0.020, p-value: 0.000
# PAY - Spearman Correlation: 0.007, p-value: 0.000
#
# Pearson Correlation Matrix (Numerical Variables Only):
#           INF_LIVE   INCOME8  MOM_LBKG   ILLB_MO
# INF_LIVE  1.000000  0.002086 -0.016010  0.007089
# INCOME8   0.002086  1.000000 -0.030529 -0.006099
# MOM_LBKG -0.016010 -0.030529  1.000000  0.069538
# ILLB_MO   0.007089 -0.006099  0.069538  1.000000

# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr, chi2_contingency
import numpy as np
import itertools

# Load data
csvfile_path = 'C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/cleanPhase8ARFv1.csv'
data = pd.read_csv(csvfile_path)

# Define variable groups
binary_categorical_vars = [
    "HISPANIC", "MARRIED", "MAT_WIC", "PAT_ACK", "BPG_DIAB8", "BPG_HBP8", "BPG_DEPRS8",
    "HTH_ASMA", "HTH_THYR", "HTH_PCOS", "HTH_ANX", "TLK_WT_RAW", "ASK_MEDS_RAW",
    "TLK_CIGS_RAW", "TLK_ETOH_RAW", "ASK_ABUS_RAW", "ASK_DPRS_RAW", "ASK_DRUG_RAW",
    "ASK_HIVT_RAW", "ASK_BF_RAW", "ASK_PPBC_RAW", "PG_GDB8", "MORB_BP8", "MH_PGDX8",
    "PAB6HUS", "PAB_XHUS", "PAB_FAM", "PAB_OTH", "PAD6HUS", "PAD_XHUS", "PAD_FAM", "PAD_OTH"
]

ordinal_categorical_vars = ["INCOME8", "MAT_DEG", "PAT_DEG", "PAY"]
regular_categorical_vars = ["STATE", "MAT_RACE_PU", "PAT_RACE_PU"]
numerical_vars = ["INCOME8", "MOM_LBKG", "ILLB_MO"]

# Pearson Correlation for Numerical vs. Numerical
print("Numerical Variable Correlations (Pearson):")
for var1, var2 in itertools.combinations(numerical_vars, 2):
    filled_var1 = data[var1].fillna(data[var1].mode()[0])
    filled_var2 = data[var2].fillna(data[var2].mode()[0])
    corr, p_value = pearsonr(filled_var1, filled_var2)
    print(f"{var1} and {var2} - Pearson Correlation: {corr:.5f}, p-value: {p_value:.5f}")

# Spearman Correlation for Ordinal Categorical vs. Ordinal Categorical
print("\nOrdinal Categorical Variable Correlations (Spearman):")
for var1, var2 in itertools.combinations(ordinal_categorical_vars, 2):
    filled_var1 = data[var1].fillna(data[var1].mode()[0])
    filled_var2 = data[var2].fillna(data[var2].mode()[0])
    corr, p_value = spearmanr(filled_var1, filled_var2)
    print(f"{var1} and {var2} - Spearman Correlation: {corr:.5f}, p-value: {p_value:.5f}")

# Chi-Square Test for Binary and Regular Categorical Variables
print("\nCategorical Variable Associations (Chi-Square Test):")
for var1, var2 in itertools.combinations(binary_categorical_vars + regular_categorical_vars, 2):
    filled_var1 = data[var1].fillna(data[var1].mode()[0])
    filled_var2 = data[var2].fillna(data[var2].mode()[0])
    contingency_table = pd.crosstab(filled_var1, filled_var2)
    chi2, p_value, _, _ = chi2_contingency(contingency_table)
    print(f"{var1} and {var2} - Chi-Square: {chi2:.5f}, p-value: {p_value:.5f}")
# Out:
# Numerical Variable Correlations (Pearson):
# INCOME8 and MOM_LBKG - Pearson Correlation: -0.03053, p-value: 0.00000
# INCOME8 and ILLB_MO - Pearson Correlation: -0.00610, p-value: 0.00258
# MOM_LBKG and ILLB_MO - Pearson Correlation: 0.06954, p-value: 0.00000
#
# Ordinal Categorical Variable Correlations (Spearman):
# INCOME8 and MAT_DEG - Spearman Correlation: 0.45040, p-value: 0.00000
# INCOME8 and PAT_DEG - Spearman Correlation: 0.43015, p-value: 0.00000
# INCOME8 and PAY - Spearman Correlation: 0.43328, p-value: 0.00000
# MAT_DEG and PAT_DEG - Spearman Correlation: 0.68074, p-value: 0.00000
# MAT_DEG and PAY - Spearman Correlation: 0.44611, p-value: 0.00000
# PAT_DEG and PAY - Spearman Correlation: 0.41820, p-value: 0.00000
#
# Categorical Variable Associations (Chi-Square Test):
# HISPANIC and MARRIED - Chi-Square: 3339.79470, p-value: 0.00000
# HISPANIC and MAT_WIC - Chi-Square: 9383.51573, p-value: 0.00000
# HISPANIC and PAT_ACK - Chi-Square: 184.51069, p-value: 0.00000
# HISPANIC and BPG_DIAB8 - Chi-Square: 0.08358, p-value: 0.77250
# HISPANIC and BPG_HBP8 - Chi-Square: 138.61839, p-value: 0.00000
# HISPANIC and BPG_DEPRS8 - Chi-Square: 915.53154, p-value: 0.00000
# HISPANIC and HTH_ASMA - Chi-Square: 102.37828, p-value: 0.00000
# HISPANIC and HTH_THYR - Chi-Square: 82.30843, p-value: 0.00000
# HISPANIC and HTH_PCOS - Chi-Square: 30.46530, p-value: 0.00000
# HISPANIC and HTH_ANX - Chi-Square: 393.54936, p-value: 0.00000
# HISPANIC and TLK_WT_RAW - Chi-Square: 38.68430, p-value: 0.00000
# HISPANIC and ASK_MEDS_RAW - Chi-Square: 1218.21407, p-value: 0.00000
# HISPANIC and TLK_CIGS_RAW - Chi-Square: 266.99211, p-value: 0.00000
# HISPANIC and TLK_ETOH_RAW - Chi-Square: 103.50943, p-value: 0.00000
# HISPANIC and ASK_ABUS_RAW - Chi-Square: 0.89870, p-value: 0.34313
# HISPANIC and ASK_DPRS_RAW - Chi-Square: 16.15414, p-value: 0.00006
# HISPANIC and ASK_DRUG_RAW - Chi-Square: 168.99126, p-value: 0.00000
# HISPANIC and ASK_HIVT_RAW - Chi-Square: 962.55907, p-value: 0.00000
# HISPANIC and ASK_BF_RAW - Chi-Square: 32.76328, p-value: 0.00000
# HISPANIC and ASK_PPBC_RAW - Chi-Square: 227.18121, p-value: 0.00000
# HISPANIC and PG_GDB8 - Chi-Square: 184.20003, p-value: 0.00000
# HISPANIC and MORB_BP8 - Chi-Square: 288.87345, p-value: 0.00000
# HISPANIC and MH_PGDX8 - Chi-Square: 393.56735, p-value: 0.00000
# HISPANIC and PAB6HUS - Chi-Square: 15.32671, p-value: 0.00009
# HISPANIC and PAB_XHUS - Chi-Square: 1.64078, p-value: 0.20022
# HISPANIC and PAB_FAM - Chi-Square: 10.93733, p-value: 0.00094
# HISPANIC and PAB_OTH - Chi-Square: 10.85862, p-value: 0.00098
# HISPANIC and PAD6HUS - Chi-Square: 2.62598, p-value: 0.10513
# HISPANIC and PAD_XHUS - Chi-Square: 0.25214, p-value: 0.61557
# HISPANIC and PAD_FAM - Chi-Square: 4.75900, p-value: 0.02915
# HISPANIC and PAD_OTH - Chi-Square: 0.03802, p-value: 0.84540
# HISPANIC and STATE - Chi-Square: 40796.76391, p-value: 0.00000
# HISPANIC and MAT_RACE_PU - Chi-Square: 28203.29112, p-value: 0.00000
# HISPANIC and PAT_RACE_PU - Chi-Square: 18690.78233, p-value: 0.00000
# MARRIED and MAT_WIC - Chi-Square: 35992.95900, p-value: 0.00000
# MARRIED and PAT_ACK - Chi-Square: 22347.75593, p-value: 0.00000
# MARRIED and BPG_DIAB8 - Chi-Square: 9.75103, p-value: 0.00179
# MARRIED and BPG_HBP8 - Chi-Square: 591.97704, p-value: 0.00000
# MARRIED and BPG_DEPRS8 - Chi-Square: 3977.23182, p-value: 0.00000
# MARRIED and HTH_ASMA - Chi-Square: 974.04523, p-value: 0.00000
# MARRIED and HTH_THYR - Chi-Square: 405.42230, p-value: 0.00000
# MARRIED and HTH_PCOS - Chi-Square: 305.65255, p-value: 0.00000
# MARRIED and HTH_ANX - Chi-Square: 870.81326, p-value: 0.00000
# MARRIED and TLK_WT_RAW - Chi-Square: 41.65137, p-value: 0.00000
# MARRIED and ASK_MEDS_RAW - Chi-Square: 1059.89997, p-value: 0.00000
# MARRIED and TLK_CIGS_RAW - Chi-Square: 58.16557, p-value: 0.00000
# MARRIED and TLK_ETOH_RAW - Chi-Square: 21.07858, p-value: 0.00000
# MARRIED and ASK_ABUS_RAW - Chi-Square: 2552.85995, p-value: 0.00000
# MARRIED and ASK_DPRS_RAW - Chi-Square: 2059.99906, p-value: 0.00000
# MARRIED and ASK_DRUG_RAW - Chi-Square: 3769.00563, p-value: 0.00000
# MARRIED and ASK_HIVT_RAW - Chi-Square: 5406.27433, p-value: 0.00000
# MARRIED and ASK_BF_RAW - Chi-Square: 1372.37867, p-value: 0.00000
# MARRIED and ASK_PPBC_RAW - Chi-Square: 3437.74948, p-value: 0.00000
# MARRIED and PG_GDB8 - Chi-Square: 128.82460, p-value: 0.00000
# MARRIED and MORB_BP8 - Chi-Square: 405.32613, p-value: 0.00000
# MARRIED and MH_PGDX8 - Chi-Square: 5017.29947, p-value: 0.00000
# MARRIED and PAB6HUS - Chi-Square: 1981.57205, p-value: 0.00000
# MARRIED and PAB_XHUS - Chi-Square: 3868.99686, p-value: 0.00000
# MARRIED and PAB_FAM - Chi-Square: 436.00252, p-value: 0.00000
# MARRIED and PAB_OTH - Chi-Square: 779.38969, p-value: 0.00000
# MARRIED and PAD6HUS - Chi-Square: 1655.75258, p-value: 0.00000
# MARRIED and PAD_XHUS - Chi-Square: 2456.11329, p-value: 0.00000
# MARRIED and PAD_FAM - Chi-Square: 341.40038, p-value: 0.00000
# MARRIED and PAD_OTH - Chi-Square: 482.87787, p-value: 0.00000
# MARRIED and STATE - Chi-Square: 9340.74925, p-value: 0.00000
# MARRIED and MAT_RACE_PU - Chi-Square: 29747.61394, p-value: 0.00000
# MARRIED and PAT_RACE_PU - Chi-Square: 10577.13128, p-value: 0.00000
# MAT_WIC and PAT_ACK - Chi-Square: 4120.89272, p-value: 0.00000
# MAT_WIC and BPG_DIAB8 - Chi-Square: 140.07017, p-value: 0.00000
# MAT_WIC and BPG_HBP8 - Chi-Square: 420.56571, p-value: 0.00000
# MAT_WIC and BPG_DEPRS8 - Chi-Square: 1906.54503, p-value: 0.00000
# MAT_WIC and HTH_ASMA - Chi-Square: 489.61180, p-value: 0.00000
# MAT_WIC and HTH_THYR - Chi-Square: 236.89884, p-value: 0.00000
# MAT_WIC and HTH_PCOS - Chi-Square: 119.18220, p-value: 0.00000
# MAT_WIC and HTH_ANX - Chi-Square: 111.72331, p-value: 0.00000
# MAT_WIC and TLK_WT_RAW - Chi-Square: 336.50823, p-value: 0.00000
# MAT_WIC and ASK_MEDS_RAW - Chi-Square: 1368.10143, p-value: 0.00000
# MAT_WIC and TLK_CIGS_RAW - Chi-Square: 22.38407, p-value: 0.00000
# MAT_WIC and TLK_ETOH_RAW - Chi-Square: 25.88399, p-value: 0.00000
# MAT_WIC and ASK_ABUS_RAW - Chi-Square: 1778.03856, p-value: 0.00000
# MAT_WIC and ASK_DPRS_RAW - Chi-Square: 1271.15491, p-value: 0.00000
# MAT_WIC and ASK_DRUG_RAW - Chi-Square: 2173.79810, p-value: 0.00000
# MAT_WIC and ASK_HIVT_RAW - Chi-Square: 3819.71005, p-value: 0.00000
# MAT_WIC and ASK_BF_RAW - Chi-Square: 1579.95469, p-value: 0.00000
# MAT_WIC and ASK_PPBC_RAW - Chi-Square: 3334.73268, p-value: 0.00000
# MAT_WIC and PG_GDB8 - Chi-Square: 64.63826, p-value: 0.00000
# MAT_WIC and MORB_BP8 - Chi-Square: 44.99296, p-value: 0.00000
# MAT_WIC and MH_PGDX8 - Chi-Square: 2310.40261, p-value: 0.00000
# MAT_WIC and PAB6HUS - Chi-Square: 867.31131, p-value: 0.00000
# MAT_WIC and PAB_XHUS - Chi-Square: 1433.86015, p-value: 0.00000
# MAT_WIC and PAB_FAM - Chi-Square: 198.17525, p-value: 0.00000
# MAT_WIC and PAB_OTH - Chi-Square: 267.36572, p-value: 0.00000
# MAT_WIC and PAD6HUS - Chi-Square: 741.89736, p-value: 0.00000
# MAT_WIC and PAD_XHUS - Chi-Square: 883.68557, p-value: 0.00000
# MAT_WIC and PAD_FAM - Chi-Square: 167.09739, p-value: 0.00000
# MAT_WIC and PAD_OTH - Chi-Square: 225.76584, p-value: 0.00000
# MAT_WIC and STATE - Chi-Square: 14030.98509, p-value: 0.00000
# MAT_WIC and MAT_RACE_PU - Chi-Square: 15295.17648, p-value: 0.00000
# MAT_WIC and PAT_RACE_PU - Chi-Square: 7947.26575, p-value: 0.00000
# PAT_ACK and BPG_DIAB8 - Chi-Square: 9.44814, p-value: 0.00211
# PAT_ACK and BPG_HBP8 - Chi-Square: 287.88532, p-value: 0.00000
# PAT_ACK and BPG_DEPRS8 - Chi-Square: 1542.54693, p-value: 0.00000
# PAT_ACK and HTH_ASMA - Chi-Square: 242.41443, p-value: 0.00000
# PAT_ACK and HTH_THYR - Chi-Square: 94.71765, p-value: 0.00000
# PAT_ACK and HTH_PCOS - Chi-Square: 54.26833, p-value: 0.00000
# PAT_ACK and HTH_ANX - Chi-Square: 349.58106, p-value: 0.00000
# PAT_ACK and TLK_WT_RAW - Chi-Square: 0.08818, p-value: 0.76651
# PAT_ACK and ASK_MEDS_RAW - Chi-Square: 366.81903, p-value: 0.00000
# PAT_ACK and TLK_CIGS_RAW - Chi-Square: 3.34517, p-value: 0.06740
# PAT_ACK and TLK_ETOH_RAW - Chi-Square: 19.91800, p-value: 0.00001
# PAT_ACK and ASK_ABUS_RAW - Chi-Square: 282.33875, p-value: 0.00000
# PAT_ACK and ASK_DPRS_RAW - Chi-Square: 383.74943, p-value: 0.00000
# PAT_ACK and ASK_DRUG_RAW - Chi-Square: 309.46573, p-value: 0.00000
# PAT_ACK and ASK_HIVT_RAW - Chi-Square: 640.35328, p-value: 0.00000
# PAT_ACK and ASK_BF_RAW - Chi-Square: 195.30066, p-value: 0.00000
# PAT_ACK and ASK_PPBC_RAW - Chi-Square: 623.74831, p-value: 0.00000
# PAT_ACK and PG_GDB8 - Chi-Square: 52.71188, p-value: 0.00000
# PAT_ACK and MORB_BP8 - Chi-Square: 157.21769, p-value: 0.00000
# PAT_ACK and MH_PGDX8 - Chi-Square: 2053.44683, p-value: 0.00000
# PAT_ACK and PAB6HUS - Chi-Square: 1696.75027, p-value: 0.00000
# PAT_ACK and PAB_XHUS - Chi-Square: 2658.88387, p-value: 0.00000
# PAT_ACK and PAB_FAM - Chi-Square: 207.00883, p-value: 0.00000
# PAT_ACK and PAB_OTH - Chi-Square: 527.00288, p-value: 0.00000
# PAT_ACK and PAD6HUS - Chi-Square: 1277.03083, p-value: 0.00000
# PAT_ACK and PAD_XHUS - Chi-Square: 2722.66566, p-value: 0.00000
# PAT_ACK and PAD_FAM - Chi-Square: 141.86411, p-value: 0.00000
# PAT_ACK and PAD_OTH - Chi-Square: 464.71539, p-value: 0.00000
# PAT_ACK and STATE - Chi-Square: 23271.42615, p-value: 0.00000
# PAT_ACK and MAT_RACE_PU - Chi-Square: 10487.36450, p-value: 0.00000
# PAT_ACK and PAT_RACE_PU - Chi-Square: 9825.12346, p-value: 0.00000
# BPG_DIAB8 and BPG_HBP8 - Chi-Square: 36095.05820, p-value: 0.00000
# BPG_DIAB8 and BPG_DEPRS8 - Chi-Square: 7999.75823, p-value: 0.00000
# BPG_DIAB8 and HTH_ASMA - Chi-Square: 6907.66912, p-value: 0.00000
# BPG_DIAB8 and HTH_THYR - Chi-Square: 12304.09281, p-value: 0.00000
# BPG_DIAB8 and HTH_PCOS - Chi-Square: 12216.70779, p-value: 0.00000
# BPG_DIAB8 and HTH_ANX - Chi-Square: 1686.90137, p-value: 0.00000
# BPG_DIAB8 and TLK_WT_RAW - Chi-Square: 11.38789, p-value: 0.00074
# BPG_DIAB8 and ASK_MEDS_RAW - Chi-Square: 7.89840, p-value: 0.00495
# BPG_DIAB8 and TLK_CIGS_RAW - Chi-Square: 55.42859, p-value: 0.00000
# BPG_DIAB8 and TLK_ETOH_RAW - Chi-Square: 52.36121, p-value: 0.00000
# BPG_DIAB8 and ASK_ABUS_RAW - Chi-Square: 11.53365, p-value: 0.00068
# BPG_DIAB8 and ASK_DPRS_RAW - Chi-Square: 0.70908, p-value: 0.39975
# BPG_DIAB8 and ASK_DRUG_RAW - Chi-Square: 0.30917, p-value: 0.57819
# BPG_DIAB8 and ASK_HIVT_RAW - Chi-Square: 2.49947, p-value: 0.11388
# BPG_DIAB8 and ASK_BF_RAW - Chi-Square: 0.74279, p-value: 0.38877
# BPG_DIAB8 and ASK_PPBC_RAW - Chi-Square: 1.28749, p-value: 0.25651
# BPG_DIAB8 and PG_GDB8 - Chi-Square: 1811.93708, p-value: 0.00000
# BPG_DIAB8 and MORB_BP8 - Chi-Square: 735.08878, p-value: 0.00000
# BPG_DIAB8 and MH_PGDX8 - Chi-Square: 64.32066, p-value: 0.00000
# BPG_DIAB8 and PAB6HUS - Chi-Square: 4.28757, p-value: 0.03839
# BPG_DIAB8 and PAB_XHUS - Chi-Square: 6.54253, p-value: 0.01053
# BPG_DIAB8 and PAB_FAM - Chi-Square: 2.43149, p-value: 0.11892
# BPG_DIAB8 and PAB_OTH - Chi-Square: 9.18257, p-value: 0.00244
# BPG_DIAB8 and PAD6HUS - Chi-Square: 8.22377, p-value: 0.00413
# BPG_DIAB8 and PAD_XHUS - Chi-Square: 12.54595, p-value: 0.00040
# BPG_DIAB8 and PAD_FAM - Chi-Square: 1.23243, p-value: 0.26694
# BPG_DIAB8 and PAD_OTH - Chi-Square: 7.90619, p-value: 0.00493
# BPG_DIAB8 and STATE - Chi-Square: 573.16803, p-value: 0.00000
# BPG_DIAB8 and MAT_RACE_PU - Chi-Square: 215.71893, p-value: 0.00000
# BPG_DIAB8 and PAT_RACE_PU - Chi-Square: 140.22693, p-value: 0.00000
# BPG_HBP8 and BPG_DEPRS8 - Chi-Square: 8450.45643, p-value: 0.00000
# BPG_HBP8 and HTH_ASMA - Chi-Square: 5154.96172, p-value: 0.00000
# BPG_HBP8 and HTH_THYR - Chi-Square: 6741.93631, p-value: 0.00000
# BPG_HBP8 and HTH_PCOS - Chi-Square: 7005.95563, p-value: 0.00000
# BPG_HBP8 and HTH_ANX - Chi-Square: 2130.34984, p-value: 0.00000
# BPG_HBP8 and TLK_WT_RAW - Chi-Square: 18.93276, p-value: 0.00001
# BPG_HBP8 and ASK_MEDS_RAW - Chi-Square: 8.87012, p-value: 0.00290
# BPG_HBP8 and TLK_CIGS_RAW - Chi-Square: 49.79944, p-value: 0.00000
# BPG_HBP8 and TLK_ETOH_RAW - Chi-Square: 66.29554, p-value: 0.00000
# BPG_HBP8 and ASK_ABUS_RAW - Chi-Square: 6.26473, p-value: 0.01232
# BPG_HBP8 and ASK_DPRS_RAW - Chi-Square: 4.75357, p-value: 0.02924
# BPG_HBP8 and ASK_DRUG_RAW - Chi-Square: 3.70957, p-value: 0.05410
# BPG_HBP8 and ASK_HIVT_RAW - Chi-Square: 56.78728, p-value: 0.00000
# BPG_HBP8 and ASK_BF_RAW - Chi-Square: 1.04361, p-value: 0.30698
# BPG_HBP8 and ASK_PPBC_RAW - Chi-Square: 9.13850, p-value: 0.00250
# BPG_HBP8 and PG_GDB8 - Chi-Square: 788.12897, p-value: 0.00000
# BPG_HBP8 and MORB_BP8 - Chi-Square: 11783.66595, p-value: 0.00000
# BPG_HBP8 and MH_PGDX8 - Chi-Square: 787.23039, p-value: 0.00000
# BPG_HBP8 and PAB6HUS - Chi-Square: 116.42121, p-value: 0.00000
# BPG_HBP8 and PAB_XHUS - Chi-Square: 121.50043, p-value: 0.00000
# BPG_HBP8 and PAB_FAM - Chi-Square: 22.16536, p-value: 0.00000
# BPG_HBP8 and PAB_OTH - Chi-Square: 62.97757, p-value: 0.00000
# BPG_HBP8 and PAD6HUS - Chi-Square: 92.83928, p-value: 0.00000
# BPG_HBP8 and PAD_XHUS - Chi-Square: 99.43070, p-value: 0.00000
# BPG_HBP8 and PAD_FAM - Chi-Square: 15.77446, p-value: 0.00007
# BPG_HBP8 and PAD_OTH - Chi-Square: 56.70120, p-value: 0.00000
# BPG_HBP8 and STATE - Chi-Square: 1345.58075, p-value: 0.00000
# BPG_HBP8 and MAT_RACE_PU - Chi-Square: 1762.21490, p-value: 0.00000
# BPG_HBP8 and PAT_RACE_PU - Chi-Square: 657.55155, p-value: 0.00000
# BPG_DEPRS8 and HTH_ASMA - Chi-Square: 5857.03693, p-value: 0.00000
# BPG_DEPRS8 and HTH_THYR - Chi-Square: 2033.54059, p-value: 0.00000
# BPG_DEPRS8 and HTH_PCOS - Chi-Square: 2707.25285, p-value: 0.00000
# BPG_DEPRS8 and HTH_ANX - Chi-Square: 35185.32763, p-value: 0.00000
# BPG_DEPRS8 and TLK_WT_RAW - Chi-Square: 120.90734, p-value: 0.00000
# BPG_DEPRS8 and ASK_MEDS_RAW - Chi-Square: 53.41030, p-value: 0.00000
# BPG_DEPRS8 and TLK_CIGS_RAW - Chi-Square: 102.14369, p-value: 0.00000
# BPG_DEPRS8 and TLK_ETOH_RAW - Chi-Square: 14.61423, p-value: 0.00013
# BPG_DEPRS8 and ASK_ABUS_RAW - Chi-Square: 218.58681, p-value: 0.00000
# BPG_DEPRS8 and ASK_DPRS_RAW - Chi-Square: 1048.26188, p-value: 0.00000
# BPG_DEPRS8 and ASK_DRUG_RAW - Chi-Square: 287.92232, p-value: 0.00000
# BPG_DEPRS8 and ASK_HIVT_RAW - Chi-Square: 0.93108, p-value: 0.33458
# BPG_DEPRS8 and ASK_BF_RAW - Chi-Square: 37.25362, p-value: 0.00000
# BPG_DEPRS8 and ASK_PPBC_RAW - Chi-Square: 63.57818, p-value: 0.00000
# BPG_DEPRS8 and PG_GDB8 - Chi-Square: 40.66510, p-value: 0.00000
# BPG_DEPRS8 and MORB_BP8 - Chi-Square: 998.88821, p-value: 0.00000
# BPG_DEPRS8 and MH_PGDX8 - Chi-Square: 94908.53751, p-value: 0.00000
# BPG_DEPRS8 and PAB6HUS - Chi-Square: 3031.51381, p-value: 0.00000
# BPG_DEPRS8 and PAB_XHUS - Chi-Square: 3697.03984, p-value: 0.00000
# BPG_DEPRS8 and PAB_FAM - Chi-Square: 733.16738, p-value: 0.00000
# BPG_DEPRS8 and PAB_OTH - Chi-Square: 1346.02701, p-value: 0.00000
# BPG_DEPRS8 and PAD6HUS - Chi-Square: 2074.06943, p-value: 0.00000
# BPG_DEPRS8 and PAD_XHUS - Chi-Square: 1920.59030, p-value: 0.00000
# BPG_DEPRS8 and PAD_FAM - Chi-Square: 404.66844, p-value: 0.00000
# BPG_DEPRS8 and PAD_OTH - Chi-Square: 773.99300, p-value: 0.00000
# BPG_DEPRS8 and STATE - Chi-Square: 3850.34896, p-value: 0.00000
# BPG_DEPRS8 and MAT_RACE_PU - Chi-Square: 2140.10428, p-value: 0.00000
# BPG_DEPRS8 and PAT_RACE_PU - Chi-Square: 2042.26780, p-value: 0.00000
# HTH_ASMA and HTH_THYR - Chi-Square: 8548.33566, p-value: 0.00000
# HTH_ASMA and HTH_PCOS - Chi-Square: 9382.26932, p-value: 0.00000
# HTH_ASMA and HTH_ANX - Chi-Square: 12677.59541, p-value: 0.00000
# HTH_ASMA and TLK_WT_RAW - Chi-Square: 0.01221, p-value: 0.91201
# HTH_ASMA and ASK_MEDS_RAW - Chi-Square: 1.94878, p-value: 0.16272
# HTH_ASMA and TLK_CIGS_RAW - Chi-Square: 27.80051, p-value: 0.00000
# HTH_ASMA and TLK_ETOH_RAW - Chi-Square: 8.29575, p-value: 0.00397
# HTH_ASMA and ASK_ABUS_RAW - Chi-Square: 61.01843, p-value: 0.00000
# HTH_ASMA and ASK_DPRS_RAW - Chi-Square: 31.60239, p-value: 0.00000
# HTH_ASMA and ASK_DRUG_RAW - Chi-Square: 67.78278, p-value: 0.00000
# HTH_ASMA and ASK_HIVT_RAW - Chi-Square: 102.51212, p-value: 0.00000
# HTH_ASMA and ASK_BF_RAW - Chi-Square: 5.86076, p-value: 0.01548
# HTH_ASMA and ASK_PPBC_RAW - Chi-Square: 6.94415, p-value: 0.00841
# HTH_ASMA and PG_GDB8 - Chi-Square: 8.83225, p-value: 0.00296
# HTH_ASMA and MORB_BP8 - Chi-Square: 330.69060, p-value: 0.00000
# HTH_ASMA and MH_PGDX8 - Chi-Square: 1679.15415, p-value: 0.00000
# HTH_ASMA and PAB6HUS - Chi-Square: 98.38501, p-value: 0.00000
# HTH_ASMA and PAB_XHUS - Chi-Square: 276.90955, p-value: 0.00000
# HTH_ASMA and PAB_FAM - Chi-Square: 98.83904, p-value: 0.00000
# HTH_ASMA and PAB_OTH - Chi-Square: 171.98536, p-value: 0.00000
# HTH_ASMA and PAD6HUS - Chi-Square: 85.98877, p-value: 0.00000
# HTH_ASMA and PAD_XHUS - Chi-Square: 127.65713, p-value: 0.00000
# HTH_ASMA and PAD_FAM - Chi-Square: 85.55234, p-value: 0.00000
# HTH_ASMA and PAD_OTH - Chi-Square: 116.17558, p-value: 0.00000
# HTH_ASMA and STATE - Chi-Square: 15249.75405, p-value: 0.00000
# HTH_ASMA and MAT_RACE_PU - Chi-Square: 751.56779, p-value: 0.00000
# HTH_ASMA and PAT_RACE_PU - Chi-Square: 316.36435, p-value: 0.00000
# HTH_THYR and HTH_PCOS - Chi-Square: 19917.76762, p-value: 0.00000
# HTH_THYR and HTH_ANX - Chi-Square: 4474.96445, p-value: 0.00000
# HTH_THYR and TLK_WT_RAW - Chi-Square: 4.73957, p-value: 0.02948
# HTH_THYR and ASK_MEDS_RAW - Chi-Square: 28.63878, p-value: 0.00000
# HTH_THYR and TLK_CIGS_RAW - Chi-Square: 6.99788, p-value: 0.00816
# HTH_THYR and TLK_ETOH_RAW - Chi-Square: 7.94828, p-value: 0.00481
# HTH_THYR and ASK_ABUS_RAW - Chi-Square: 146.48448, p-value: 0.00000
# HTH_THYR and ASK_DPRS_RAW - Chi-Square: 178.24771, p-value: 0.00000
# HTH_THYR and ASK_DRUG_RAW - Chi-Square: 85.39860, p-value: 0.00000
# HTH_THYR and ASK_HIVT_RAW - Chi-Square: 18.56998, p-value: 0.00002
# HTH_THYR and ASK_BF_RAW - Chi-Square: 96.96847, p-value: 0.00000
# HTH_THYR and ASK_PPBC_RAW - Chi-Square: 214.60079, p-value: 0.00000
# HTH_THYR and PG_GDB8 - Chi-Square: 77.54182, p-value: 0.00000
# HTH_THYR and MORB_BP8 - Chi-Square: 89.92507, p-value: 0.00000
# HTH_THYR and MH_PGDX8 - Chi-Square: 29.95850, p-value: 0.00000
# HTH_THYR and PAB6HUS - Chi-Square: 3.90495, p-value: 0.04814
# HTH_THYR and PAB_XHUS - Chi-Square: 7.44443, p-value: 0.00636
# HTH_THYR and PAB_FAM - Chi-Square: 2.00920, p-value: 0.15635
# HTH_THYR and PAB_OTH - Chi-Square: 2.07189, p-value: 0.15004
# HTH_THYR and PAD6HUS - Chi-Square: 2.31425, p-value: 0.12819
# HTH_THYR and PAD_XHUS - Chi-Square: 0.31601, p-value: 0.57402
# HTH_THYR and PAD_FAM - Chi-Square: 8.36689, p-value: 0.00382
# HTH_THYR and PAD_OTH - Chi-Square: 1.11343, p-value: 0.29134
# HTH_THYR and STATE - Chi-Square: 9937.77047, p-value: 0.00000
# HTH_THYR and MAT_RACE_PU - Chi-Square: 678.70841, p-value: 0.00000
# HTH_THYR and PAT_RACE_PU - Chi-Square: 550.14532, p-value: 0.00000
# HTH_PCOS and HTH_ANX - Chi-Square: 5272.06989, p-value: 0.00000
# HTH_PCOS and TLK_WT_RAW - Chi-Square: 16.93020, p-value: 0.00004
# HTH_PCOS and ASK_MEDS_RAW - Chi-Square: 25.59193, p-value: 0.00000
# HTH_PCOS and TLK_CIGS_RAW - Chi-Square: 0.32938, p-value: 0.56602
# HTH_PCOS and TLK_ETOH_RAW - Chi-Square: 0.07036, p-value: 0.79082
# HTH_PCOS and ASK_ABUS_RAW - Chi-Square: 41.61076, p-value: 0.00000
# HTH_PCOS and ASK_DPRS_RAW - Chi-Square: 76.23712, p-value: 0.00000
# HTH_PCOS and ASK_DRUG_RAW - Chi-Square: 17.50697, p-value: 0.00003
# HTH_PCOS and ASK_HIVT_RAW - Chi-Square: 8.74203, p-value: 0.00311
# HTH_PCOS and ASK_BF_RAW - Chi-Square: 100.44317, p-value: 0.00000
# HTH_PCOS and ASK_PPBC_RAW - Chi-Square: 236.88756, p-value: 0.00000
# HTH_PCOS and PG_GDB8 - Chi-Square: 320.53449, p-value: 0.00000
# HTH_PCOS and MORB_BP8 - Chi-Square: 318.26154, p-value: 0.00000
# HTH_PCOS and MH_PGDX8 - Chi-Square: 83.62201, p-value: 0.00000
# HTH_PCOS and PAB6HUS - Chi-Square: 0.01935, p-value: 0.88936
# HTH_PCOS and PAB_XHUS - Chi-Square: 1.34319, p-value: 0.24647
# HTH_PCOS and PAB_FAM - Chi-Square: 5.26256, p-value: 0.02179
# HTH_PCOS and PAB_OTH - Chi-Square: 11.43609, p-value: 0.00072
# HTH_PCOS and PAD6HUS - Chi-Square: 0.01672, p-value: 0.89711
# HTH_PCOS and PAD_XHUS - Chi-Square: 0.00150, p-value: 0.96906
# HTH_PCOS and PAD_FAM - Chi-Square: 4.93366, p-value: 0.02634
# HTH_PCOS and PAD_OTH - Chi-Square: 6.44581, p-value: 0.01112
# HTH_PCOS and STATE - Chi-Square: 10157.15868, p-value: 0.00000
# HTH_PCOS and MAT_RACE_PU - Chi-Square: 384.42355, p-value: 0.00000
# HTH_PCOS and PAT_RACE_PU - Chi-Square: 196.73217, p-value: 0.00000
# HTH_ANX and TLK_WT_RAW - Chi-Square: 118.31957, p-value: 0.00000
# HTH_ANX and ASK_MEDS_RAW - Chi-Square: 97.26444, p-value: 0.00000
# HTH_ANX and TLK_CIGS_RAW - Chi-Square: 63.75922, p-value: 0.00000
# HTH_ANX and TLK_ETOH_RAW - Chi-Square: 25.73395, p-value: 0.00000
# HTH_ANX and ASK_ABUS_RAW - Chi-Square: 0.80805, p-value: 0.36870
# HTH_ANX and ASK_DPRS_RAW - Chi-Square: 102.92659, p-value: 0.00000
# HTH_ANX and ASK_DRUG_RAW - Chi-Square: 7.44983, p-value: 0.00634
# HTH_ANX and ASK_HIVT_RAW - Chi-Square: 15.53133, p-value: 0.00008
# HTH_ANX and ASK_BF_RAW - Chi-Square: 33.65705, p-value: 0.00000
# HTH_ANX and ASK_PPBC_RAW - Chi-Square: 55.98030, p-value: 0.00000
# HTH_ANX and PG_GDB8 - Chi-Square: 10.44212, p-value: 0.00123
# HTH_ANX and MORB_BP8 - Chi-Square: 572.84549, p-value: 0.00000
# HTH_ANX and MH_PGDX8 - Chi-Square: 20209.22482, p-value: 0.00000
# HTH_ANX and PAB6HUS - Chi-Square: 831.19056, p-value: 0.00000
# HTH_ANX and PAB_XHUS - Chi-Square: 1105.67973, p-value: 0.00000
# HTH_ANX and PAB_FAM - Chi-Square: 314.60903, p-value: 0.00000
# HTH_ANX and PAB_OTH - Chi-Square: 381.52603, p-value: 0.00000
# HTH_ANX and PAD6HUS - Chi-Square: 579.55504, p-value: 0.00000
# HTH_ANX and PAD_XHUS - Chi-Square: 566.74699, p-value: 0.00000
# HTH_ANX and PAD_FAM - Chi-Square: 225.49258, p-value: 0.00000
# HTH_ANX and PAD_OTH - Chi-Square: 212.72988, p-value: 0.00000
# HTH_ANX and STATE - Chi-Square: 39027.75618, p-value: 0.00000
# HTH_ANX and MAT_RACE_PU - Chi-Square: 1697.07105, p-value: 0.00000
# HTH_ANX and PAT_RACE_PU - Chi-Square: 1673.62416, p-value: 0.00000
# TLK_WT_RAW and ASK_MEDS_RAW - Chi-Square: 3610.52552, p-value: 0.00000
# TLK_WT_RAW and TLK_CIGS_RAW - Chi-Square: 2391.97839, p-value: 0.00000
# TLK_WT_RAW and TLK_ETOH_RAW - Chi-Square: 3044.14744, p-value: 0.00000
# TLK_WT_RAW and ASK_ABUS_RAW - Chi-Square: 9763.70798, p-value: 0.00000
# TLK_WT_RAW and ASK_DPRS_RAW - Chi-Square: 9911.19485, p-value: 0.00000
# TLK_WT_RAW and ASK_DRUG_RAW - Chi-Square: 7155.68194, p-value: 0.00000
# TLK_WT_RAW and ASK_HIVT_RAW - Chi-Square: 13814.38673, p-value: 0.00000
# TLK_WT_RAW and ASK_BF_RAW - Chi-Square: 6430.22776, p-value: 0.00000
# TLK_WT_RAW and ASK_PPBC_RAW - Chi-Square: 7756.35525, p-value: 0.00000
# TLK_WT_RAW and PG_GDB8 - Chi-Square: 101.22609, p-value: 0.00000
# TLK_WT_RAW and MORB_BP8 - Chi-Square: 6.06658, p-value: 0.01378
# TLK_WT_RAW and MH_PGDX8 - Chi-Square: 156.30086, p-value: 0.00000
# TLK_WT_RAW and PAB6HUS - Chi-Square: 17.22163, p-value: 0.00003
# TLK_WT_RAW and PAB_XHUS - Chi-Square: 3.84118, p-value: 0.05001
# TLK_WT_RAW and PAB_FAM - Chi-Square: 10.19212, p-value: 0.00141
# TLK_WT_RAW and PAB_OTH - Chi-Square: 7.75575, p-value: 0.00535
# TLK_WT_RAW and PAD6HUS - Chi-Square: 4.91484, p-value: 0.02663
# TLK_WT_RAW and PAD_XHUS - Chi-Square: 1.82422, p-value: 0.17681
# TLK_WT_RAW and PAD_FAM - Chi-Square: 2.19692, p-value: 0.13829
# TLK_WT_RAW and PAD_OTH - Chi-Square: 1.75531, p-value: 0.18521
# TLK_WT_RAW and STATE - Chi-Square: 1588.87442, p-value: 0.00000
# TLK_WT_RAW and MAT_RACE_PU - Chi-Square: 415.64918, p-value: 0.00000
# TLK_WT_RAW and PAT_RACE_PU - Chi-Square: 377.80733, p-value: 0.00000
# ASK_MEDS_RAW and TLK_CIGS_RAW - Chi-Square: 42309.64886, p-value: 0.00000
# ASK_MEDS_RAW and TLK_ETOH_RAW - Chi-Square: 38977.13179, p-value: 0.00000
# ASK_MEDS_RAW and ASK_ABUS_RAW - Chi-Square: 7961.70896, p-value: 0.00000
# ASK_MEDS_RAW and ASK_DPRS_RAW - Chi-Square: 9476.83567, p-value: 0.00000
# ASK_MEDS_RAW and ASK_DRUG_RAW - Chi-Square: 11119.08802, p-value: 0.00000
# ASK_MEDS_RAW and ASK_HIVT_RAW - Chi-Square: 2434.66886, p-value: 0.00000
# ASK_MEDS_RAW and ASK_BF_RAW - Chi-Square: 4542.31717, p-value: 0.00000
# ASK_MEDS_RAW and ASK_PPBC_RAW - Chi-Square: 2106.41355, p-value: 0.00000
# ASK_MEDS_RAW and PG_GDB8 - Chi-Square: 5.45889, p-value: 0.01947
# ASK_MEDS_RAW and MORB_BP8 - Chi-Square: 24.92862, p-value: 0.00000
# ASK_MEDS_RAW and MH_PGDX8 - Chi-Square: 17.45563, p-value: 0.00003
# ASK_MEDS_RAW and PAB6HUS - Chi-Square: 31.56993, p-value: 0.00000
# ASK_MEDS_RAW and PAB_XHUS - Chi-Square: 44.29479, p-value: 0.00000
# ASK_MEDS_RAW and PAB_FAM - Chi-Square: 9.14182, p-value: 0.00250
# ASK_MEDS_RAW and PAB_OTH - Chi-Square: 21.17482, p-value: 0.00000
# ASK_MEDS_RAW and PAD6HUS - Chi-Square: 23.42595, p-value: 0.00000
# ASK_MEDS_RAW and PAD_XHUS - Chi-Square: 50.44794, p-value: 0.00000
# ASK_MEDS_RAW and PAD_FAM - Chi-Square: 12.41714, p-value: 0.00043
# ASK_MEDS_RAW and PAD_OTH - Chi-Square: 15.21375, p-value: 0.00010
# ASK_MEDS_RAW and STATE - Chi-Square: 1531.75422, p-value: 0.00000
# ASK_MEDS_RAW and MAT_RACE_PU - Chi-Square: 1151.30292, p-value: 0.00000
# ASK_MEDS_RAW and PAT_RACE_PU - Chi-Square: 431.90613, p-value: 0.00000
# TLK_CIGS_RAW and TLK_ETOH_RAW - Chi-Square: 174200.35557, p-value: 0.00000
# TLK_CIGS_RAW and ASK_ABUS_RAW - Chi-Square: 24009.17048, p-value: 0.00000
# TLK_CIGS_RAW and ASK_DPRS_RAW - Chi-Square: 23502.71219, p-value: 0.00000
# TLK_CIGS_RAW and ASK_DRUG_RAW - Chi-Square: 40883.72617, p-value: 0.00000
# TLK_CIGS_RAW and ASK_HIVT_RAW - Chi-Square: 7561.28254, p-value: 0.00000
# TLK_CIGS_RAW and ASK_BF_RAW - Chi-Square: 8976.34640, p-value: 0.00000
# TLK_CIGS_RAW and ASK_PPBC_RAW - Chi-Square: 5127.83113, p-value: 0.00000
# TLK_CIGS_RAW and PG_GDB8 - Chi-Square: 1.14290, p-value: 0.28504
# TLK_CIGS_RAW and MORB_BP8 - Chi-Square: 20.27725, p-value: 0.00001
# TLK_CIGS_RAW and MH_PGDX8 - Chi-Square: 73.99554, p-value: 0.00000
# TLK_CIGS_RAW and PAB6HUS - Chi-Square: 0.00000, p-value: 1.00000
# TLK_CIGS_RAW and PAB_XHUS - Chi-Square: 5.09131, p-value: 0.02405
# TLK_CIGS_RAW and PAB_FAM - Chi-Square: 0.44362, p-value: 0.50538
# TLK_CIGS_RAW and PAB_OTH - Chi-Square: 0.08737, p-value: 0.76755
# TLK_CIGS_RAW and PAD6HUS - Chi-Square: 0.21193, p-value: 0.64526
# TLK_CIGS_RAW and PAD_XHUS - Chi-Square: 0.43249, p-value: 0.51077
# TLK_CIGS_RAW and PAD_FAM - Chi-Square: 3.32873, p-value: 0.06808
# TLK_CIGS_RAW and PAD_OTH - Chi-Square: 4.83594, p-value: 0.02787
# TLK_CIGS_RAW and STATE - Chi-Square: 2097.22550, p-value: 0.00000
# TLK_CIGS_RAW and MAT_RACE_PU - Chi-Square: 247.87481, p-value: 0.00000
# TLK_CIGS_RAW and PAT_RACE_PU - Chi-Square: 201.37692, p-value: 0.00000
# TLK_ETOH_RAW and ASK_ABUS_RAW - Chi-Square: 27377.76812, p-value: 0.00000
# TLK_ETOH_RAW and ASK_DPRS_RAW - Chi-Square: 25947.90502, p-value: 0.00000
# TLK_ETOH_RAW and ASK_DRUG_RAW - Chi-Square: 46749.64730, p-value: 0.00000
# TLK_ETOH_RAW and ASK_HIVT_RAW - Chi-Square: 8664.95255, p-value: 0.00000
# TLK_ETOH_RAW and ASK_BF_RAW - Chi-Square: 9881.80837, p-value: 0.00000
# TLK_ETOH_RAW and ASK_PPBC_RAW - Chi-Square: 5548.76687, p-value: 0.00000
# TLK_ETOH_RAW and PG_GDB8 - Chi-Square: 0.64293, p-value: 0.42265
# TLK_ETOH_RAW and MORB_BP8 - Chi-Square: 9.05811, p-value: 0.00262
# TLK_ETOH_RAW and MH_PGDX8 - Chi-Square: 16.05827, p-value: 0.00006
# TLK_ETOH_RAW and PAB6HUS - Chi-Square: 7.77050, p-value: 0.00531
# TLK_ETOH_RAW and PAB_XHUS - Chi-Square: 2.93183, p-value: 0.08685
# TLK_ETOH_RAW and PAB_FAM - Chi-Square: 1.72981, p-value: 0.18844
# TLK_ETOH_RAW and PAB_OTH - Chi-Square: 9.70637, p-value: 0.00184
# TLK_ETOH_RAW and PAD6HUS - Chi-Square: 9.61344, p-value: 0.00193
# TLK_ETOH_RAW and PAD_XHUS - Chi-Square: 8.80677, p-value: 0.00300
# TLK_ETOH_RAW and PAD_FAM - Chi-Square: 14.54911, p-value: 0.00014
# TLK_ETOH_RAW and PAD_OTH - Chi-Square: 15.64948, p-value: 0.00008
# TLK_ETOH_RAW and STATE - Chi-Square: 2229.51445, p-value: 0.00000
# TLK_ETOH_RAW and MAT_RACE_PU - Chi-Square: 110.78603, p-value: 0.00000
# TLK_ETOH_RAW and PAT_RACE_PU - Chi-Square: 89.63046, p-value: 0.00000
# ASK_ABUS_RAW and ASK_DPRS_RAW - Chi-Square: 100071.77033, p-value: 0.00000
# ASK_ABUS_RAW and ASK_DRUG_RAW - Chi-Square: 57367.09786, p-value: 0.00000
# ASK_ABUS_RAW and ASK_HIVT_RAW - Chi-Square: 26685.02128, p-value: 0.00000
# ASK_ABUS_RAW and ASK_BF_RAW - Chi-Square: 13410.97245, p-value: 0.00000
# ASK_ABUS_RAW and ASK_PPBC_RAW - Chi-Square: 14192.99919, p-value: 0.00000
# ASK_ABUS_RAW and PG_GDB8 - Chi-Square: 128.21347, p-value: 0.00000
# ASK_ABUS_RAW and MORB_BP8 - Chi-Square: 145.13912, p-value: 0.00000
# ASK_ABUS_RAW and MH_PGDX8 - Chi-Square: 249.97234, p-value: 0.00000
# ASK_ABUS_RAW and PAB6HUS - Chi-Square: 30.41374, p-value: 0.00000
# ASK_ABUS_RAW and PAB_XHUS - Chi-Square: 120.35342, p-value: 0.00000
# ASK_ABUS_RAW and PAB_FAM - Chi-Square: 3.21340, p-value: 0.07304
# ASK_ABUS_RAW and PAB_OTH - Chi-Square: 10.64006, p-value: 0.00111
# ASK_ABUS_RAW and PAD6HUS - Chi-Square: 22.84048, p-value: 0.00000
# ASK_ABUS_RAW and PAD_XHUS - Chi-Square: 71.04122, p-value: 0.00000
# ASK_ABUS_RAW and PAD_FAM - Chi-Square: 1.74974, p-value: 0.18591
# ASK_ABUS_RAW and PAD_OTH - Chi-Square: 5.01332, p-value: 0.02515
# ASK_ABUS_RAW and STATE - Chi-Square: 13606.27565, p-value: 0.00000
# ASK_ABUS_RAW and MAT_RACE_PU - Chi-Square: 2825.22111, p-value: 0.00000
# ASK_ABUS_RAW and PAT_RACE_PU - Chi-Square: 1283.34526, p-value: 0.00000
# ASK_DPRS_RAW and ASK_DRUG_RAW - Chi-Square: 52841.78324, p-value: 0.00000
# ASK_DPRS_RAW and ASK_HIVT_RAW - Chi-Square: 23251.16659, p-value: 0.00000
# ASK_DPRS_RAW and ASK_BF_RAW - Chi-Square: 18927.88759, p-value: 0.00000
# ASK_DPRS_RAW and ASK_PPBC_RAW - Chi-Square: 18318.62431, p-value: 0.00000
# ASK_DPRS_RAW and PG_GDB8 - Chi-Square: 49.30914, p-value: 0.00000
# ASK_DPRS_RAW and MORB_BP8 - Chi-Square: 55.82187, p-value: 0.00000
# ASK_DPRS_RAW and MH_PGDX8 - Chi-Square: 1122.12085, p-value: 0.00000
# ASK_DPRS_RAW and PAB6HUS - Chi-Square: 13.18990, p-value: 0.00028
# ASK_DPRS_RAW and PAB_XHUS - Chi-Square: 77.96294, p-value: 0.00000
# ASK_DPRS_RAW and PAB_FAM - Chi-Square: 2.81770, p-value: 0.09323
# ASK_DPRS_RAW and PAB_OTH - Chi-Square: 15.53418, p-value: 0.00008
# ASK_DPRS_RAW and PAD6HUS - Chi-Square: 6.28249, p-value: 0.01219
# ASK_DPRS_RAW and PAD_XHUS - Chi-Square: 45.75567, p-value: 0.00000
# ASK_DPRS_RAW and PAD_FAM - Chi-Square: 0.01358, p-value: 0.90724
# ASK_DPRS_RAW and PAD_OTH - Chi-Square: 8.84871, p-value: 0.00293
# ASK_DPRS_RAW and STATE - Chi-Square: 9249.52734, p-value: 0.00000
# ASK_DPRS_RAW and MAT_RACE_PU - Chi-Square: 1862.26536, p-value: 0.00000
# ASK_DPRS_RAW and PAT_RACE_PU - Chi-Square: 767.04794, p-value: 0.00000
# ASK_DRUG_RAW and ASK_HIVT_RAW - Chi-Square: 30547.04653, p-value: 0.00000
# ASK_DRUG_RAW and ASK_BF_RAW - Chi-Square: 12492.87132, p-value: 0.00000
# ASK_DRUG_RAW and ASK_PPBC_RAW - Chi-Square: 11920.61835, p-value: 0.00000
# ASK_DRUG_RAW and PG_GDB8 - Chi-Square: 64.68387, p-value: 0.00000
# ASK_DRUG_RAW and MORB_BP8 - Chi-Square: 145.34202, p-value: 0.00000
# ASK_DRUG_RAW and MH_PGDX8 - Chi-Square: 302.62558, p-value: 0.00000
# ASK_DRUG_RAW and PAB6HUS - Chi-Square: 49.82478, p-value: 0.00000
# ASK_DRUG_RAW and PAB_XHUS - Chi-Square: 150.43074, p-value: 0.00000
# ASK_DRUG_RAW and PAB_FAM - Chi-Square: 17.69689, p-value: 0.00003
# ASK_DRUG_RAW and PAB_OTH - Chi-Square: 11.03055, p-value: 0.00090
# ASK_DRUG_RAW and PAD6HUS - Chi-Square: 34.17263, p-value: 0.00000
# ASK_DRUG_RAW and PAD_XHUS - Chi-Square: 59.20955, p-value: 0.00000
# ASK_DRUG_RAW and PAD_FAM - Chi-Square: 8.54372, p-value: 0.00347
# ASK_DRUG_RAW and PAD_OTH - Chi-Square: 2.52762, p-value: 0.11187
# ASK_DRUG_RAW and STATE - Chi-Square: 5310.41854, p-value: 0.00000
# ASK_DRUG_RAW and MAT_RACE_PU - Chi-Square: 1886.43707, p-value: 0.00000
# ASK_DRUG_RAW and PAT_RACE_PU - Chi-Square: 890.78244, p-value: 0.00000
# ASK_HIVT_RAW and ASK_BF_RAW - Chi-Square: 10371.04613, p-value: 0.00000
# ASK_HIVT_RAW and ASK_PPBC_RAW - Chi-Square: 13623.91542, p-value: 0.00000
# ASK_HIVT_RAW and PG_GDB8 - Chi-Square: 15.03739, p-value: 0.00011
# ASK_HIVT_RAW and MORB_BP8 - Chi-Square: 15.55860, p-value: 0.00008
# ASK_HIVT_RAW and MH_PGDX8 - Chi-Square: 4.48448, p-value: 0.03420
# ASK_HIVT_RAW and PAB6HUS - Chi-Square: 36.98977, p-value: 0.00000
# ASK_HIVT_RAW and PAB_XHUS - Chi-Square: 173.57636, p-value: 0.00000
# ASK_HIVT_RAW and PAB_FAM - Chi-Square: 7.91536, p-value: 0.00490
# ASK_HIVT_RAW and PAB_OTH - Chi-Square: 16.49705, p-value: 0.00005
# ASK_HIVT_RAW and PAD6HUS - Chi-Square: 35.62045, p-value: 0.00000
# ASK_HIVT_RAW and PAD_XHUS - Chi-Square: 126.45206, p-value: 0.00000
# ASK_HIVT_RAW and PAD_FAM - Chi-Square: 4.44034, p-value: 0.03510
# ASK_HIVT_RAW and PAD_OTH - Chi-Square: 13.58976, p-value: 0.00023
# ASK_HIVT_RAW and STATE - Chi-Square: 5030.39924, p-value: 0.00000
# ASK_HIVT_RAW and MAT_RACE_PU - Chi-Square: 3976.32849, p-value: 0.00000
# ASK_HIVT_RAW and PAT_RACE_PU - Chi-Square: 1836.61770, p-value: 0.00000
# ASK_BF_RAW and ASK_PPBC_RAW - Chi-Square: 38131.24156, p-value: 0.00000
# ASK_BF_RAW and PG_GDB8 - Chi-Square: 20.28291, p-value: 0.00001
# ASK_BF_RAW and MORB_BP8 - Chi-Square: 10.48951, p-value: 0.00120
# ASK_BF_RAW and MH_PGDX8 - Chi-Square: 33.59661, p-value: 0.00000
# ASK_BF_RAW and PAB6HUS - Chi-Square: 1.04341, p-value: 0.30703
# ASK_BF_RAW and PAB_XHUS - Chi-Square: 8.96619, p-value: 0.00275
# ASK_BF_RAW and PAB_FAM - Chi-Square: 0.13629, p-value: 0.71200
# ASK_BF_RAW and PAB_OTH - Chi-Square: 0.94532, p-value: 0.33091
# ASK_BF_RAW and PAD6HUS - Chi-Square: 0.75284, p-value: 0.38558
# ASK_BF_RAW and PAD_XHUS - Chi-Square: 2.94780, p-value: 0.08599
# ASK_BF_RAW and PAD_FAM - Chi-Square: 0.06834, p-value: 0.79378
# ASK_BF_RAW and PAD_OTH - Chi-Square: 0.03549, p-value: 0.85058
# ASK_BF_RAW and STATE - Chi-Square: 2778.96849, p-value: 0.00000
# ASK_BF_RAW and MAT_RACE_PU - Chi-Square: 1132.84718, p-value: 0.00000
# ASK_BF_RAW and PAT_RACE_PU - Chi-Square: 752.64810, p-value: 0.00000
# ASK_PPBC_RAW and PG_GDB8 - Chi-Square: 0.39087, p-value: 0.53184
# ASK_PPBC_RAW and MORB_BP8 - Chi-Square: 0.86129, p-value: 0.35338
# ASK_PPBC_RAW and MH_PGDX8 - Chi-Square: 107.06021, p-value: 0.00000
# ASK_PPBC_RAW and PAB6HUS - Chi-Square: 20.71702, p-value: 0.00001
# ASK_PPBC_RAW and PAB_XHUS - Chi-Square: 54.02824, p-value: 0.00000
# ASK_PPBC_RAW and PAB_FAM - Chi-Square: 3.57752, p-value: 0.05857
# ASK_PPBC_RAW and PAB_OTH - Chi-Square: 0.22015, p-value: 0.63892
# ASK_PPBC_RAW and PAD6HUS - Chi-Square: 13.53235, p-value: 0.00023
# ASK_PPBC_RAW and PAD_XHUS - Chi-Square: 16.34005, p-value: 0.00005
# ASK_PPBC_RAW and PAD_FAM - Chi-Square: 2.32249, p-value: 0.12752
# ASK_PPBC_RAW and PAD_OTH - Chi-Square: 6.94814, p-value: 0.00839
# ASK_PPBC_RAW and STATE - Chi-Square: 4281.38370, p-value: 0.00000
# ASK_PPBC_RAW and MAT_RACE_PU - Chi-Square: 2590.48425, p-value: 0.00000
# ASK_PPBC_RAW and PAT_RACE_PU - Chi-Square: 1371.30111, p-value: 0.00000
# PG_GDB8 and MORB_BP8 - Chi-Square: 2540.51772, p-value: 0.00000
# PG_GDB8 and MH_PGDX8 - Chi-Square: 338.81780, p-value: 0.00000
# PG_GDB8 and PAB6HUS - Chi-Square: 2.90851, p-value: 0.08811
# PG_GDB8 and PAB_XHUS - Chi-Square: 0.37993, p-value: 0.53764
# PG_GDB8 and PAB_FAM - Chi-Square: 0.16063, p-value: 0.68858
# PG_GDB8 and PAB_OTH - Chi-Square: 0.66589, p-value: 0.41449
# PG_GDB8 and PAD6HUS - Chi-Square: 2.52142, p-value: 0.11231
# PG_GDB8 and PAD_XHUS - Chi-Square: 0.02019, p-value: 0.88701
# PG_GDB8 and PAD_FAM - Chi-Square: 0.25166, p-value: 0.61591
# PG_GDB8 and PAD_OTH - Chi-Square: 2.92079, p-value: 0.08744
# PG_GDB8 and STATE - Chi-Square: 852.62701, p-value: 0.00000
# PG_GDB8 and MAT_RACE_PU - Chi-Square: 1653.68416, p-value: 0.00000
# PG_GDB8 and PAT_RACE_PU - Chi-Square: 1216.92891, p-value: 0.00000
# MORB_BP8 and MH_PGDX8 - Chi-Square: 2551.39141, p-value: 0.00000
# MORB_BP8 and PAB6HUS - Chi-Square: 46.85490, p-value: 0.00000
# MORB_BP8 and PAB_XHUS - Chi-Square: 92.71993, p-value: 0.00000
# MORB_BP8 and PAB_FAM - Chi-Square: 23.48660, p-value: 0.00000
# MORB_BP8 and PAB_OTH - Chi-Square: 25.22528, p-value: 0.00000
# MORB_BP8 and PAD6HUS - Chi-Square: 42.51194, p-value: 0.00000
# MORB_BP8 and PAD_XHUS - Chi-Square: 50.88991, p-value: 0.00000
# MORB_BP8 and PAD_FAM - Chi-Square: 16.63432, p-value: 0.00005
# MORB_BP8 and PAD_OTH - Chi-Square: 32.74575, p-value: 0.00000
# MORB_BP8 and STATE - Chi-Square: 1916.45593, p-value: 0.00000
# MORB_BP8 and MAT_RACE_PU - Chi-Square: 1148.73045, p-value: 0.00000
# MORB_BP8 and PAT_RACE_PU - Chi-Square: 742.54936, p-value: 0.00000
# MH_PGDX8 and PAB6HUS - Chi-Square: 3599.63631, p-value: 0.00000
# MH_PGDX8 and PAB_XHUS - Chi-Square: 3949.92047, p-value: 0.00000
# MH_PGDX8 and PAB_FAM - Chi-Square: 709.76191, p-value: 0.00000
# MH_PGDX8 and PAB_OTH - Chi-Square: 1441.89438, p-value: 0.00000
# MH_PGDX8 and PAD6HUS - Chi-Square: 2872.02949, p-value: 0.00000
# MH_PGDX8 and PAD_XHUS - Chi-Square: 2395.78809, p-value: 0.00000
# MH_PGDX8 and PAD_FAM - Chi-Square: 548.62454, p-value: 0.00000
# MH_PGDX8 and PAD_OTH - Chi-Square: 1091.21382, p-value: 0.00000
# MH_PGDX8 and STATE - Chi-Square: 2968.04694, p-value: 0.00000
# MH_PGDX8 and MAT_RACE_PU - Chi-Square: 1742.81769, p-value: 0.00000
# MH_PGDX8 and PAT_RACE_PU - Chi-Square: 1454.76032, p-value: 0.00000
# PAB6HUS and PAB_XHUS - Chi-Square: 18201.88851, p-value: 0.00000
# PAB6HUS and PAB_FAM - Chi-Square: 2290.49210, p-value: 0.00000
# PAB6HUS and PAB_OTH - Chi-Square: 2592.95128, p-value: 0.00000
# PAB6HUS and PAD6HUS - Chi-Square: 98227.08823, p-value: 0.00000
# PAB6HUS and PAD_XHUS - Chi-Square: 14685.85114, p-value: 0.00000
# PAB6HUS and PAD_FAM - Chi-Square: 944.36461, p-value: 0.00000
# PAB6HUS and PAD_OTH - Chi-Square: 1556.51832, p-value: 0.00000
# PAB6HUS and STATE - Chi-Square: 597.54845, p-value: 0.00000
# PAB6HUS and MAT_RACE_PU - Chi-Square: 1078.85281, p-value: 0.00000
# PAB6HUS and PAT_RACE_PU - Chi-Square: 359.08533, p-value: 0.00000
# PAB_XHUS and PAB_FAM - Chi-Square: 1491.44313, p-value: 0.00000
# PAB_XHUS and PAB_OTH - Chi-Square: 2863.34345, p-value: 0.00000
# PAB_XHUS and PAD6HUS - Chi-Square: 8958.83846, p-value: 0.00000
# PAB_XHUS and PAD_XHUS - Chi-Square: 75300.27815, p-value: 0.00000
# PAB_XHUS and PAD_FAM - Chi-Square: 684.41595, p-value: 0.00000
# PAB_XHUS and PAD_OTH - Chi-Square: 1143.83444, p-value: 0.00000
# PAB_XHUS and STATE - Chi-Square: 519.63455, p-value: 0.00000
# PAB_XHUS and MAT_RACE_PU - Chi-Square: 862.79942, p-value: 0.00000
# PAB_XHUS and PAT_RACE_PU - Chi-Square: 313.03658, p-value: 0.00000
# PAB_FAM and PAB_OTH - Chi-Square: 4034.90944, p-value: 0.00000
# PAB_FAM and PAD6HUS - Chi-Square: 1121.29659, p-value: 0.00000
# PAB_FAM and PAD_XHUS - Chi-Square: 689.17873, p-value: 0.00000
# PAB_FAM and PAD_FAM - Chi-Square: 61935.00452, p-value: 0.00000
# PAB_FAM and PAD_OTH - Chi-Square: 2153.80567, p-value: 0.00000
# PAB_FAM and STATE - Chi-Square: 1012.94186, p-value: 0.00000
# PAB_FAM and MAT_RACE_PU - Chi-Square: 174.00431, p-value: 0.00000
# PAB_FAM and PAT_RACE_PU - Chi-Square: 106.43198, p-value: 0.00000
# PAB_OTH and PAD6HUS - Chi-Square: 1481.66500, p-value: 0.00000
# PAB_OTH and PAD_XHUS - Chi-Square: 1470.40126, p-value: 0.00000
# PAB_OTH and PAD_FAM - Chi-Square: 1976.15623, p-value: 0.00000
# PAB_OTH and PAD_OTH - Chi-Square: 62910.19995, p-value: 0.00000
# PAB_OTH and STATE - Chi-Square: 1331.14360, p-value: 0.00000
# PAB_OTH and MAT_RACE_PU - Chi-Square: 542.98646, p-value: 0.00000
# PAB_OTH and PAT_RACE_PU - Chi-Square: 288.69302, p-value: 0.00000
# PAD6HUS and PAD_XHUS - Chi-Square: 15513.10355, p-value: 0.00000
# PAD6HUS and PAD_FAM - Chi-Square: 1331.48365, p-value: 0.00000
# PAD6HUS and PAD_OTH - Chi-Square: 1645.16145, p-value: 0.00000
# PAD6HUS and STATE - Chi-Square: 438.35442, p-value: 0.00000
# PAD6HUS and MAT_RACE_PU - Chi-Square: 871.07963, p-value: 0.00000
# PAD6HUS and PAT_RACE_PU - Chi-Square: 287.18337, p-value: 0.00000
# PAD_XHUS and PAD_FAM - Chi-Square: 963.09034, p-value: 0.00000
# PAD_XHUS and PAD_OTH - Chi-Square: 1605.09538, p-value: 0.00000
# PAD_XHUS and STATE - Chi-Square: 370.67451, p-value: 0.00000
# PAD_XHUS and MAT_RACE_PU - Chi-Square: 704.91747, p-value: 0.00000
# PAD_XHUS and PAT_RACE_PU - Chi-Square: 176.00717, p-value: 0.00000
# PAD_FAM and PAD_OTH - Chi-Square: 2966.93795, p-value: 0.00000
# PAD_FAM and STATE - Chi-Square: 862.71233, p-value: 0.00000
# PAD_FAM and MAT_RACE_PU - Chi-Square: 135.03699, p-value: 0.00000
# PAD_FAM and PAT_RACE_PU - Chi-Square: 66.57057, p-value: 0.00000
# PAD_OTH and STATE - Chi-Square: 1116.10859, p-value: 0.00000
# PAD_OTH and MAT_RACE_PU - Chi-Square: 340.28516, p-value: 0.00000
# PAD_OTH and PAT_RACE_PU - Chi-Square: 100.99384, p-value: 0.00000
# STATE and MAT_RACE_PU - Chi-Square: 126453.65272, p-value: 0.00000
# STATE and PAT_RACE_PU - Chi-Square: 93005.52294, p-value: 0.00000
# MAT_RACE_PU and PAT_RACE_PU - Chi-Square: 473678.62386, p-value: 0.00000

# %%
#Class Imbalance
import pandas as pd

csvfile_path = 'C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/rawPhase8ARF.csv'

rawPhase8ARF = pd.read_csv(csvfile_path)

target_variables = ["INF_LIVE"]

# Function to calculate the count and percentage of each group
def calculate_distribution(df, column):
    count_table = df[column].value_counts(dropna=False)
    percentage_table = df[column].value_counts(normalize=True, dropna=False) * 100
    distribution_table = pd.DataFrame({'Count': count_table, 'Percentage': percentage_table})
    return distribution_table

# Display the distribution of each target variable
for target in target_variables:
    print(f'\nDistribution for {target}:\n')
    print(calculate_distribution(rawPhase8ARF, target))
# Out:
# C:\Users\kentv\AppData\Local\Temp\ipykernel_18236\1544193342.py:6: DtypeWarning: Columns (459,462,463,464,465,466) have mixed types. Specify dtype option on import or set low_memory=False.
#   rawPhase8ARF = pd.read_csv(csvfile_path)
# Distribution for INF_LIVE:
#
#            Count  Percentage
# INF_LIVE
# 2.0       242062   96.836420
# NaN         5756    2.302676
# 1.0         2152    0.860903

# %%
# Split Test and Training and Apply SMOTE Only
import pandas as pd 
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

csvfile_path = 'C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/cleanPhase8ARFv1.csv'
data = pd.read_csv(csvfile_path)

# Define features and target variable, excluding ID from features
X = data.drop(columns=["INF_LIVE", "ID"])
y = data["INF_LIVE"]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Output the initial class distribution
print("Class distribution before SMOTE:")
print(y_train.value_counts())

# Apply SMOTE to oversample the minority class to match the majority class
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_smote, y_smote = smote.fit_resample(X_train, y_train)

# Output the class distribution after SMOTE
print("\nClass distribution after SMOTE:")
print(y_smote.value_counts())

# Create a DataFrame for the balanced data
balanced_data = pd.DataFrame(X_smote, columns=X.columns)
balanced_data['INF_LIVE'] = y_smote.values

# Save the balanced data to a new CSV file
output_file_path = "C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/cleanPhase8ARFv2.csv"
balanced_data.to_csv(output_file_path, index=False)

print(f"\nBalanced dataset saved to {output_file_path}")
# Out:
# Class distribution before SMOTE:
# INF_LIVE
# 2.0    118076
# 1.0       977
# Name: count, dtype: int64
#
# Class distribution after SMOTE:
# INF_LIVE
# 2.0    118076
# 1.0    118076
# Name: count, dtype: int64
#
# Balanced dataset saved to C:/Users/kentv/Desktop/ML/ML Proj - PRAM/Data/raw/cleanPhase8ARFv2.csv
